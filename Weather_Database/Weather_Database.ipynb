# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 714

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port hardy
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | sechura
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | lavumisa
# Processing Record 10 of Set 1 | batticaloa
# Processing Record 11 of Set 1 | tongliao
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | shingu
# Processing Record 17 of Set 1 | tubigan
# Processing Record 18 of Set 1 | san francisco
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | sergeyevka
# Processing Record 24 of Set 1 | koumac
# Processing Record 25 of Set 1 | whitianga
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | yushan
# Processing Record 28 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | kidal
# Processing Record 31 of Set 1 | sorland
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | luwingu
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | marrakesh
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | aktau
# Processing Record 40 of Set 1 | penarroya-pueblonuevo
# Processing Record 41 of Set 1 | ligayan
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | businga
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | olafsvik
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | husavik
# Processing Record 48 of Set 1 | pisco
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 2 | petrovsk
# Processing Record 3 of Set 2 | cockburn town
# Processing Record 4 of Set 2 | luba
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | luang prabang
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | kabare
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | maralal
# Processing Record 13 of Set 2 | sobolevo
# Processing Record 14 of Set 2 | yuancheng
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | hualmay
# Processing Record 20 of Set 2 | beloha
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | kargasok
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | coihaique
# Processing Record 28 of Set 2 | korla
# Processing Record 29 of Set 2 | ust-nera
# Processing Record 30 of Set 2 | sanmenxia
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | kampot
# Processing Record 34 of Set 2 | hobyo
# Processing Record 35 of Set 2 | jiazi
# Processing Record 36 of Set 2 | healdsburg
# Processing Record 37 of Set 2 | vila franca do campo
# Processing Record 38 of Set 2 | urengoy
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | talbahat
# Processing Record 41 of Set 2 | faanui
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | buritis
# Processing Record 45 of Set 2 | gorzow wielkopolski
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | sakakah
# Processing Record 48 of Set 2 | champerico
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | thessalon
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | norman
# Processing Record 3 of Set 3 | broken hill
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | norrtalje
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | kiunga
# Processing Record 12 of Set 3 | muhos
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | geilo
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | bubaque
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | lubu
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | verkhnyaya toyma
# Processing Record 24 of Set 3 | san cristobal
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | mangai
# Processing Record 27 of Set 3 | taltal
# Processing Record 28 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 3 | ushuaia
# Processing Record 30 of Set 3 | weligama
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | tarata
# Processing Record 33 of Set 3 | youghal
# Processing Record 34 of Set 3 | lagoa
# Processing Record 35 of Set 3 | tessalit
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | olinda
# Processing Record 38 of Set 3 | mananara
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | mananjary
# Processing Record 43 of Set 3 | sitka
# Processing Record 44 of Set 3 | bukachacha
# Processing Record 45 of Set 3 | takoradi
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | chara
# Processing Record 48 of Set 3 | ostrovnoy
# Processing Record 49 of Set 3 | gamba
# Processing Record 50 of Set 3 | ahipara
# Processing Record 1 of Set 4 | pierre
# Processing Record 2 of Set 4 | mount isa
# Processing Record 3 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 4 | ancud
# Processing Record 8 of Set 4 | vanimo
# Processing Record 9 of Set 4 | los llanos de aridane
# Processing Record 10 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 4 | waingapu
# Processing Record 12 of Set 4 | pindiga
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | slave lake
# Processing Record 16 of Set 4 | montrose
# Processing Record 17 of Set 4 | zaranj
# Processing Record 18 of Set 4 | suarez
# Processing Record 19 of Set 4 | stromness
# Processing Record 20 of Set 4 | camacha
# Processing Record 21 of Set 4 | manggar
# Processing Record 22 of Set 4 | jiuquan
# Processing Record 23 of Set 4 | amapa
# Processing Record 24 of Set 4 | diamantino
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | bandeirantes
# Processing Record 27 of Set 4 | avera
# Processing Record 28 of Set 4 | yumen
# Processing Record 29 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | araouane
# Processing Record 32 of Set 4 | bac lieu
# Processing Record 33 of Set 4 | ayorou
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | sain alto
# Processing Record 36 of Set 4 | eyl
# Processing Record 37 of Set 4 | potgietersrus
# City not found. Skipping...
# Processing Record 38 of Set 4 | marion
# Processing Record 39 of Set 4 | porbandar
# Processing Record 40 of Set 4 | sangmelima
# Processing Record 41 of Set 4 | nakhon nayok
# Processing Record 42 of Set 4 | guangzhou
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | sarkhej
# Processing Record 45 of Set 4 | burns lake
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | chiredzi
# Processing Record 48 of Set 4 | mawlaik
# Processing Record 49 of Set 4 | ustka
# Processing Record 50 of Set 4 | port alfred
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | quatre cocos
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | langham
# Processing Record 6 of Set 5 | kamphaeng phet
# Processing Record 7 of Set 5 | port augusta
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | santiago del estero
# Processing Record 10 of Set 5 | verin
# Processing Record 11 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 12 of Set 5 | toora-khem
# Processing Record 13 of Set 5 | sterling
# Processing Record 14 of Set 5 | baykit
# Processing Record 15 of Set 5 | phangnga
# Processing Record 16 of Set 5 | the valley
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | wanaka
# Processing Record 19 of Set 5 | taunggyi
# Processing Record 20 of Set 5 | milkovo
# Processing Record 21 of Set 5 | bay roberts
# Processing Record 22 of Set 5 | shimoda
# Processing Record 23 of Set 5 | shirokiy
# Processing Record 24 of Set 5 | zyryanka
# Processing Record 25 of Set 5 | pangody
# Processing Record 26 of Set 5 | haines junction
# Processing Record 27 of Set 5 | hibbing
# Processing Record 28 of Set 5 | thompson
# Processing Record 29 of Set 5 | marihatag
# Processing Record 30 of Set 5 | mayo
# Processing Record 31 of Set 5 | mount gambier
# Processing Record 32 of Set 5 | codrington
# Processing Record 33 of Set 5 | araceli
# Processing Record 34 of Set 5 | moron
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | brandenburg
# Processing Record 37 of Set 5 | kropotkin
# Processing Record 38 of Set 5 | bud
# Processing Record 39 of Set 5 | cayenne
# Processing Record 40 of Set 5 | mahebourg
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | budogoshch
# Processing Record 43 of Set 5 | buin
# Processing Record 44 of Set 5 | gazanjyk
# Processing Record 45 of Set 5 | stolin
# Processing Record 46 of Set 5 | mumford
# Processing Record 47 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 5 | karratha
# Processing Record 49 of Set 5 | biltine
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | torbay
# Processing Record 2 of Set 6 | chake chake
# Processing Record 3 of Set 6 | vardo
# Processing Record 4 of Set 6 | lander
# Processing Record 5 of Set 6 | agadez
# Processing Record 6 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 6 | conakry
# Processing Record 8 of Set 6 | luohe
# Processing Record 9 of Set 6 | la carlota
# Processing Record 10 of Set 6 | charters towers
# Processing Record 11 of Set 6 | tiarei
# Processing Record 12 of Set 6 | nome
# Processing Record 13 of Set 6 | hamilton
# Processing Record 14 of Set 6 | antalaha
# Processing Record 15 of Set 6 | dikson
# Processing Record 16 of Set 6 | somova
# Processing Record 17 of Set 6 | san policarpo
# Processing Record 18 of Set 6 | chino valley
# Processing Record 19 of Set 6 | annau
# Processing Record 20 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | urumqi
# Processing Record 23 of Set 6 | necochea
# Processing Record 24 of Set 6 | tadine
# Processing Record 25 of Set 6 | tahe
# Processing Record 26 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 6 | jeremie
# Processing Record 28 of Set 6 | mahon
# Processing Record 29 of Set 6 | savannah bight
# Processing Record 30 of Set 6 | college
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | sembakung
# Processing Record 33 of Set 6 | havre-saint-pierre
# Processing Record 34 of Set 6 | te anau
# Processing Record 35 of Set 6 | kaeo
# Processing Record 36 of Set 6 | vila
# Processing Record 37 of Set 6 | sligo
# Processing Record 38 of Set 6 | pangnirtung
# Processing Record 39 of Set 6 | bengkulu
# Processing Record 40 of Set 6 | sombrerete
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | varhaug
# Processing Record 43 of Set 6 | homer
# Processing Record 44 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 6 | gushi
# Processing Record 47 of Set 6 | ambatofinandrahana
# Processing Record 48 of Set 6 | lingao
# Processing Record 49 of Set 6 | askim
# Processing Record 50 of Set 6 | rincon
# Processing Record 1 of Set 7 | sabratah
# Processing Record 2 of Set 7 | fort nelson
# Processing Record 3 of Set 7 | maningrida
# Processing Record 4 of Set 7 | cascais
# Processing Record 5 of Set 7 | surovikino
# Processing Record 6 of Set 7 | chirilagua
# Processing Record 7 of Set 7 | joshimath
# Processing Record 8 of Set 7 | navabad
# City not found. Skipping...
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | cabo san lucas
# Processing Record 11 of Set 7 | vestmannaeyjar
# Processing Record 12 of Set 7 | ribeira grande
# Processing Record 13 of Set 7 | yulara
# Processing Record 14 of Set 7 | moose factory
# Processing Record 15 of Set 7 | benghazi
# Processing Record 16 of Set 7 | kundiawa
# Processing Record 17 of Set 7 | esso
# Processing Record 18 of Set 7 | adrar
# Processing Record 19 of Set 7 | port blair
# Processing Record 20 of Set 7 | teya
# Processing Record 21 of Set 7 | saint george
# Processing Record 22 of Set 7 | la macarena
# Processing Record 23 of Set 7 | san miguel
# Processing Record 24 of Set 7 | pangkalanbuun
# Processing Record 25 of Set 7 | pietarsaari
# Processing Record 26 of Set 7 | vostok
# Processing Record 27 of Set 7 | ziro
# Processing Record 28 of Set 7 | dingle
# Processing Record 29 of Set 7 | mae sai
# Processing Record 30 of Set 7 | christchurch
# Processing Record 31 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 7 | san quintin
# Processing Record 33 of Set 7 | peiting
# Processing Record 34 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 7 | teguldet
# Processing Record 36 of Set 7 | ilawe
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | anloga
# Processing Record 39 of Set 7 | hambantota
# Processing Record 40 of Set 7 | sinnar
# Processing Record 41 of Set 7 | talaya
# Processing Record 42 of Set 7 | tianmen
# Processing Record 43 of Set 7 | yinchuan
# Processing Record 44 of Set 7 | sola
# Processing Record 45 of Set 7 | filingue
# Processing Record 46 of Set 7 | itaituba
# Processing Record 47 of Set 7 | jacksonville
# Processing Record 48 of Set 7 | mehran
# Processing Record 49 of Set 7 | high level
# Processing Record 50 of Set 7 | iqaluit
# Processing Record 1 of Set 8 | shorapur
# Processing Record 2 of Set 8 | mocuba
# Processing Record 3 of Set 8 | atar
# Processing Record 4 of Set 8 | buxar
# Processing Record 5 of Set 8 | calabozo
# Processing Record 6 of Set 8 | santa rosalia
# Processing Record 7 of Set 8 | vestmanna
# Processing Record 8 of Set 8 | brae
# Processing Record 9 of Set 8 | kutum
# Processing Record 10 of Set 8 | isangel
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 13 of Set 8 | guekedou
# City not found. Skipping...
# Processing Record 14 of Set 8 | noumea
# Processing Record 15 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 8 | zhezkazgan
# Processing Record 17 of Set 8 | aketi
# Processing Record 18 of Set 8 | mangrol
# Processing Record 19 of Set 8 | tual
# Processing Record 20 of Set 8 | nouadhibou
# Processing Record 21 of Set 8 | sarakhs
# Processing Record 22 of Set 8 | venustiano carranza
# Processing Record 23 of Set 8 | wairoa
# Processing Record 24 of Set 8 | abu samrah
# Processing Record 25 of Set 8 | lavrentiya
# Processing Record 26 of Set 8 | tuatapere
# Processing Record 27 of Set 8 | tautira
# Processing Record 28 of Set 8 | mayumba
# Processing Record 29 of Set 8 | changping
# Processing Record 30 of Set 8 | dolores
# Processing Record 31 of Set 8 | laguna
# Processing Record 32 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 8 | rio gallegos
# Processing Record 34 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 8 | katobu
# Processing Record 36 of Set 8 | meulaboh
# Processing Record 37 of Set 8 | mackay
# Processing Record 38 of Set 8 | bako
# Processing Record 39 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 8 | la ronge
# Processing Record 41 of Set 8 | naze
# Processing Record 42 of Set 8 | victoria
# Processing Record 43 of Set 8 | iquitos
# Processing Record 44 of Set 8 | dingzhou
# Processing Record 45 of Set 8 | uyuni
# Processing Record 46 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 8 | bambanglipuro
# Processing Record 48 of Set 8 | nanortalik
# Processing Record 49 of Set 8 | kerema
# Processing Record 50 of Set 8 | poum
# Processing Record 1 of Set 9 | meadow lake
# Processing Record 2 of Set 9 | strezhevoy
# Processing Record 3 of Set 9 | fairbanks
# Processing Record 4 of Set 9 | susuman
# Processing Record 5 of Set 9 | namibe
# Processing Record 6 of Set 9 | santa maria
# Processing Record 7 of Set 9 | baruun-urt
# Processing Record 8 of Set 9 | bathsheba
# Processing Record 9 of Set 9 | marsa matruh
# Processing Record 10 of Set 9 | nyrob
# Processing Record 11 of Set 9 | rochegda
# Processing Record 12 of Set 9 | aranos
# Processing Record 13 of Set 9 | bereznik
# Processing Record 14 of Set 9 | santa vitoria do palmar
# Processing Record 15 of Set 9 | omaha
# Processing Record 16 of Set 9 | pundaguitan
# Processing Record 17 of Set 9 | siguiri
# Processing Record 18 of Set 9 | ust-kuyga
# Processing Record 19 of Set 9 | bandarbeyla
# Processing Record 20 of Set 9 | sosnovo-ozerskoye
# Processing Record 21 of Set 9 | pemangkat
# Processing Record 22 of Set 9 | kasongo-lunda
# Processing Record 23 of Set 9 | ubinskoye
# Processing Record 24 of Set 9 | darhan
# Processing Record 25 of Set 9 | asau
# Processing Record 26 of Set 9 | garissa
# Processing Record 27 of Set 9 | shizunai
# Processing Record 28 of Set 9 | reforma
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | skjervoy
# Processing Record 31 of Set 9 | gamboma
# Processing Record 32 of Set 9 | nguru
# Processing Record 33 of Set 9 | fatehgarh
# Processing Record 34 of Set 9 | yambio
# Processing Record 35 of Set 9 | arrecife
# Processing Record 36 of Set 9 | castlerea
# Processing Record 37 of Set 9 | pekan
# Processing Record 38 of Set 9 | gelibolu
# Processing Record 39 of Set 9 | ketchikan
# Processing Record 40 of Set 9 | xacmaz
# Processing Record 41 of Set 9 | presidente medici
# Processing Record 42 of Set 9 | kendari
# Processing Record 43 of Set 9 | pacifica
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | natal
# Processing Record 46 of Set 9 | bethel
# Processing Record 47 of Set 9 | arbazh
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | anage
# Processing Record 1 of Set 10 | powell river
# Processing Record 2 of Set 10 | moses lake
# Processing Record 3 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 10 | zhigansk
# Processing Record 5 of Set 10 | fare
# Processing Record 6 of Set 10 | waipawa
# Processing Record 7 of Set 10 | dalvik
# Processing Record 8 of Set 10 | qaqortoq
# Processing Record 9 of Set 10 | ginda
# Processing Record 10 of Set 10 | ngunguru
# Processing Record 11 of Set 10 | salalah
# Processing Record 12 of Set 10 | pilar
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | ulaanbaatar
# Processing Record 15 of Set 10 | san jose
# Processing Record 16 of Set 10 | kosai
# Processing Record 17 of Set 10 | kaliua
# Processing Record 18 of Set 10 | bershet
# Processing Record 19 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 20 of Set 10 | alice springs
# Processing Record 21 of Set 10 | mao
# Processing Record 22 of Set 10 | andenes
# Processing Record 23 of Set 10 | jaumave
# Processing Record 24 of Set 10 | usevya
# Processing Record 25 of Set 10 | tarapur
# Processing Record 26 of Set 10 | talavera
# Processing Record 27 of Set 10 | itoman
# Processing Record 28 of Set 10 | emerald
# Processing Record 29 of Set 10 | praia
# Processing Record 30 of Set 10 | lasa
# Processing Record 31 of Set 10 | lgov
# Processing Record 32 of Set 10 | turan
# Processing Record 33 of Set 10 | touros
# Processing Record 34 of Set 10 | huarmey
# Processing Record 35 of Set 10 | kathmandu
# Processing Record 36 of Set 10 | jambi
# Processing Record 37 of Set 10 | seoul
# Processing Record 38 of Set 10 | gushikawa
# Processing Record 39 of Set 10 | bethanien
# Processing Record 40 of Set 10 | kibiti
# Processing Record 41 of Set 10 | garden city
# Processing Record 42 of Set 10 | buala
# Processing Record 43 of Set 10 | ixtapa
# Processing Record 44 of Set 10 | berlevag
# Processing Record 45 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 46 of Set 10 | aktash
# Processing Record 47 of Set 10 | jalu
# Processing Record 48 of Set 10 | silver city
# Processing Record 49 of Set 10 | saint-pierre
# Processing Record 50 of Set 10 | usinsk
# Processing Record 1 of Set 11 | navalmoral de la mata
# Processing Record 2 of Set 11 | yar-sale
# Processing Record 3 of Set 11 | fukue
# Processing Record 4 of Set 11 | mahalapye
# Processing Record 5 of Set 11 | borogontsy
# Processing Record 6 of Set 11 | mishawaka
# Processing Record 7 of Set 11 | matagami
# Processing Record 8 of Set 11 | zemio
# Processing Record 9 of Set 11 | kamaishi
# Processing Record 10 of Set 11 | colac
# Processing Record 11 of Set 11 | chiang kham
# Processing Record 12 of Set 11 | mandera
# Processing Record 13 of Set 11 | ola
# Processing Record 14 of Set 11 | povenets
# Processing Record 15 of Set 11 | yakima
# Processing Record 16 of Set 11 | saint-philippe
# Processing Record 17 of Set 11 | marzuq
# Processing Record 18 of Set 11 | hasaki
# Processing Record 19 of Set 11 | haverfordwest
# Processing Record 20 of Set 11 | praia da vitoria
# Processing Record 21 of Set 11 | plouzane
# Processing Record 22 of Set 11 | liepaja
# Processing Record 23 of Set 11 | atherton
# Processing Record 24 of Set 11 | knyaginino
# Processing Record 25 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 26 of Set 11 | honiara
# Processing Record 27 of Set 11 | broome
# Processing Record 28 of Set 11 | khartoum
# Processing Record 29 of Set 11 | palasa
# Processing Record 30 of Set 11 | clinton
# Processing Record 31 of Set 11 | lae
# Processing Record 32 of Set 11 | maniitsoq
# Processing Record 33 of Set 11 | sunrise manor
# Processing Record 34 of Set 11 | sao filipe
# Processing Record 35 of Set 11 | shuangcheng
# Processing Record 36 of Set 11 | kumo
# Processing Record 37 of Set 11 | umm kaddadah
# Processing Record 38 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 11 | harper
# Processing Record 40 of Set 11 | egvekinot
# Processing Record 41 of Set 11 | normandin
# Processing Record 42 of Set 11 | les cayes
# Processing Record 43 of Set 11 | saint-sauveur-des-monts
# Processing Record 44 of Set 11 | souillac
# Processing Record 45 of Set 11 | colares
# Processing Record 46 of Set 11 | oneonta
# Processing Record 47 of Set 11 | columbus
# Processing Record 48 of Set 11 | cangzhou
# Processing Record 49 of Set 11 | acapulco
# Processing Record 50 of Set 11 | marsabit
# Processing Record 1 of Set 12 | loiza
# Processing Record 2 of Set 12 | jiwani
# Processing Record 3 of Set 12 | jizan
# Processing Record 4 of Set 12 | tomatlan
# Processing Record 5 of Set 12 | pareora
# Processing Record 6 of Set 12 | portland
# Processing Record 7 of Set 12 | sharjah
# Processing Record 8 of Set 12 | mogwase
# Processing Record 9 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 12 | neyshabur
# Processing Record 11 of Set 12 | kristianstad
# Processing Record 12 of Set 12 | pitimbu
# Processing Record 13 of Set 12 | isla mujeres
# Processing Record 14 of Set 12 | alekseyevsk
# Processing Record 15 of Set 12 | amuntai
# Processing Record 16 of Set 12 | aasiaat
# Processing Record 17 of Set 12 | gualaquiza
# Processing Record 18 of Set 12 | charlestown
# Processing Record 19 of Set 12 | riyadh
# Processing Record 20 of Set 12 | redcliffe
# Processing Record 21 of Set 12 | luanda
# Processing Record 22 of Set 12 | mogadishu
# Processing Record 23 of Set 12 | leeds
# Processing Record 24 of Set 12 | tura
# Processing Record 25 of Set 12 | awjilah
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | alekseyevka
# Processing Record 28 of Set 12 | camana
# Processing Record 29 of Set 12 | redan
# Processing Record 30 of Set 12 | birjand
# Processing Record 31 of Set 12 | duz
# City not found. Skipping...
# Processing Record 32 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 12 | barinas
# Processing Record 34 of Set 12 | alta floresta
# Processing Record 35 of Set 12 | faya
# Processing Record 36 of Set 12 | aklavik
# Processing Record 37 of Set 12 | uyemskiy
# Processing Record 38 of Set 12 | khudumelapye
# Processing Record 39 of Set 12 | dubrovnik
# Processing Record 40 of Set 12 | korem
# Processing Record 41 of Set 12 | mokhsogollokh
# Processing Record 42 of Set 12 | sambava
# Processing Record 43 of Set 12 | hagersville
# Processing Record 44 of Set 12 | otane
# Processing Record 45 of Set 12 | ambon
# Processing Record 46 of Set 12 | yol
# Processing Record 47 of Set 12 | novoagansk
# Processing Record 48 of Set 12 | solnechnyy
# Processing Record 49 of Set 12 | kayerkan
# Processing Record 50 of Set 12 | sao joao da barra
# Processing Record 1 of Set 13 | bonfim
# Processing Record 2 of Set 13 | portel
# Processing Record 3 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 13 | hovd
# Processing Record 5 of Set 13 | verkhoyansk
# Processing Record 6 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 13 | birkeland
# Processing Record 8 of Set 13 | key west
# Processing Record 9 of Set 13 | caravelas
# Processing Record 10 of Set 13 | ilulissat
# Processing Record 11 of Set 13 | filadelfia
# Processing Record 12 of Set 13 | bonavista
# Processing Record 13 of Set 13 | borazjan
# Processing Record 14 of Set 13 | moyale
# Processing Record 15 of Set 13 | north platte
# Processing Record 16 of Set 13 | martyush
# Processing Record 17 of Set 13 | saskatoon
# Processing Record 18 of Set 13 | hami
# Processing Record 19 of Set 13 | ambilobe
# Processing Record 20 of Set 13 | tottori
# Processing Record 21 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 13 | zvishavane
# Processing Record 23 of Set 13 | novobureyskiy
# Processing Record 24 of Set 13 | hefei
# Processing Record 25 of Set 13 | sijunjung
# Processing Record 26 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 13 | oranjestad
# Processing Record 28 of Set 13 | taoudenni
# Processing Record 29 of Set 13 | hirara
# Processing Record 30 of Set 13 | sumbe
# Processing Record 31 of Set 13 | fortuna
# Processing Record 32 of Set 13 | trincomalee
# Processing Record 33 of Set 13 | krasyliv
# Processing Record 34 of Set 13 | muros
# Processing Record 35 of Set 13 | goure
# Processing Record 36 of Set 13 | maldonado
# Processing Record 37 of Set 13 | leh
# Processing Record 38 of Set 13 | russell
# Processing Record 39 of Set 13 | olga
# Processing Record 40 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 13 | vredendal
# Processing Record 42 of Set 13 | margate
# Processing Record 43 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 13 | temerloh
# Processing Record 45 of Set 13 | harboore
# Processing Record 46 of Set 13 | chistogorskiy
# Processing Record 47 of Set 13 | parry sound
# Processing Record 48 of Set 13 | sao jose da coroa grande
# Processing Record 49 of Set 13 | nyurba
# Processing Record 50 of Set 13 | oriximina
# Processing Record 1 of Set 14 | lafia
# Processing Record 2 of Set 14 | vao
# Processing Record 3 of Set 14 | matay
# Processing Record 4 of Set 14 | zupanja
# Processing Record 5 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 6 of Set 14 | grand-santi
# Processing Record 7 of Set 14 | belyy yar
# Processing Record 8 of Set 14 | turbat
# Processing Record 9 of Set 14 | khani
# Processing Record 10 of Set 14 | robinson
# Processing Record 11 of Set 14 | kurilsk
# Processing Record 12 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 14 | ankara
# Processing Record 14 of Set 14 | richards bay
# Processing Record 15 of Set 14 | giaveno
# Processing Record 16 of Set 14 | junin
# Processing Record 17 of Set 14 | tucuman
# Processing Record 18 of Set 14 | havelock
# Processing Record 19 of Set 14 | golden gate
# Processing Record 20 of Set 14 | orthez
# Processing Record 21 of Set 14 | beirut
# Processing Record 22 of Set 14 | bireun
# Processing Record 23 of Set 14 | mehamn
# Processing Record 24 of Set 14 | poltavka
# Processing Record 25 of Set 14 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 14 | malanville
# Processing Record 27 of Set 14 | puerto el triunfo
# Processing Record 28 of Set 14 | milicz
# Processing Record 29 of Set 14 | whithorn
# Processing Record 30 of Set 14 | itarema
# Processing Record 31 of Set 14 | tello
# Processing Record 32 of Set 14 | ambulu
# Processing Record 33 of Set 14 | fonte boa
# Processing Record 34 of Set 14 | maceio
# Processing Record 35 of Set 14 | rucheng
# Processing Record 36 of Set 14 | channel-port aux basques
# Processing Record 37 of Set 14 | garmsar
# Processing Record 38 of Set 14 | cardoso
# Processing Record 39 of Set 14 | paamiut
# Processing Record 40 of Set 14 | erzurum
# Processing Record 41 of Set 14 | chapais
# Processing Record 42 of Set 14 | daru
# Processing Record 43 of Set 14 | aksu
# Processing Record 44 of Set 14 | mariel
# Processing Record 45 of Set 14 | meybod
# Processing Record 46 of Set 14 | lokosovo
# Processing Record 47 of Set 14 | valdivia
# Processing Record 48 of Set 14 | launceston
# Processing Record 49 of Set 14 | caucaia
# Processing Record 50 of Set 14 | bantva
# Processing Record 1 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 15 | maryborough
# Processing Record 3 of Set 15 | innisfail
# Processing Record 4 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 15 | gurlan
# Processing Record 6 of Set 15 | henzada
# City not found. Skipping...
# Processing Record 7 of Set 15 | imeni poliny osipenko
# Processing Record 8 of Set 15 | sarh
# Processing Record 9 of Set 15 | mathathane
# Processing Record 10 of Set 15 | balikpapan
# Processing Record 11 of Set 15 | port-gentil
# Processing Record 12 of Set 15 | coolum beach
# Processing Record 13 of Set 15 | kijini
# Processing Record 14 of Set 15 | heishan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 658

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Hardy  50.6996 -127.4199     35.78        93          75
# 1  Mar Del Plata -38.0023  -57.5575     89.83        77           0
# 2          Kapaa  22.0752 -159.3190     79.12        83         100
# 3        Sechura  -5.5569  -80.8222     76.39        58          12
# 4         Albany  42.6001  -73.9662     42.73        47         100
# 5        Mataura -46.1927  168.8643     50.49        99         100
# 6       Lavumisa -27.3100   31.8920     67.39        96         100
# 7     Batticaloa   7.7102   81.6924     76.75        84          95
# 8       Tongliao  43.6125  122.2653      8.40        59           0
# 9   Punta Arenas -53.1500  -70.9167     50.11        40          40
#
#    Wind Speed Country Current Description
# 0        0.00      CA       broken clouds
# 1       20.00      AR           clear sky
# 2       12.66      US       moderate rain
# 3       14.63      PE          few clouds
# 4        1.01      US     overcast clouds
# 5        2.13      NZ     overcast clouds
# 6        5.68      SZ          light rain
# 7        7.85      LK     overcast clouds
# 8        9.66      CN           clear sky
# 9       19.57      CL    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Hardy      CA  50.6996 -127.4199     35.78        93          75
# 1  Mar Del Plata      AR -38.0023  -57.5575     89.83        77           0
# 2          Kapaa      US  22.0752 -159.3190     79.12        83         100
# 3        Sechura      PE  -5.5569  -80.8222     76.39        58          12
# 4         Albany      US  42.6001  -73.9662     42.73        47         100
# 5        Mataura      NZ -46.1927  168.8643     50.49        99         100
# 6       Lavumisa      SZ -27.3100   31.8920     67.39        96         100
# 7     Batticaloa      LK   7.7102   81.6924     76.75        84          95
# 8       Tongliao      CN  43.6125  122.2653      8.40        59           0
# 9   Punta Arenas      CL -53.1500  -70.9167     50.11        40          40
#
#    Wind Speed Current Description
# 0        0.00       broken clouds
# 1       20.00           clear sky
# 2       12.66       moderate rain
# 3       14.63          few clouds
# 4        1.01     overcast clouds
# 5        2.13     overcast clouds
# 6        5.68          light rain
# 7        7.85     overcast clouds
# 8        9.66           clear sky
# 9       19.57    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
